# %% [markdown]
# ## Ungraded Questions

# %% [markdown]
# ### 1) Start by importing all important libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable

# %%
df=pd.read_csv('SA2021_W1_Pokemon.csv')
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### 3) Display shape of dataframe

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
df.drop('#',axis=1,inplace=True)
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
df.set_index(['Name'],inplace=True)
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary
# Name
# Bulbasaur                   65     45           1      False
# Ivysaur                     80     60           1      False
# Venusaur                   100     80           1      False
# VenusaurMega Venusaur      120     80           1      False
# Charmander                  50     65           1      False

# %% [markdown]
# ### 7) Print a list of all the unique Type-1 powers

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
df['Type-3']=df['Type 1'] + "+" + df['Type 2']
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary        Type-3
# Name
# Bulbasaur                   65     45           1      False  Grass+Poison
# Ivysaur                     80     60           1      False  Grass+Poison
# Venusaur                   100     80           1      False  Grass+Poison
# VenusaurMega Venusaur      120     80           1      False  Grass+Poison
# Charmander                  50     65           1      False           NaN

# %%
df[df['Type 1']=="Psychic"]
# Out:
#                           Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# Abra                     Psychic       NaN    310   25      20       15
# Kadabra                  Psychic       NaN    400   40      35       30
# Alakazam                 Psychic       NaN    500   55      50       45
# AlakazamMega Alakazam    Psychic       NaN    590   55      50       65
# Drowzee                  Psychic       NaN    328   60      48       45
# Hypno                    Psychic       NaN    483   85      73       70
# Mr. Mime                 Psychic     Fairy    460   40      45       65
# Mewtwo                   Psychic       NaN    680  106     110       90
# MewtwoMega Mewtwo X      Psychic  Fighting    780  106     190      100
# MewtwoMega Mewtwo Y      Psychic       NaN    780  106     150       70
# Mew                      Psychic       NaN    600  100     100      100
# Natu                     Psychic    Flying    320   40      50       45
# ...

# %%
df[df['Type 2']=="Flying"]
# Out:
#                              Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Charizard                      Fire  Flying    534   78      84       78
# CharizardMega Charizard Y      Fire  Flying    634   78     104       78
# Butterfree                      Bug  Flying    395   60      45       50
# Pidgey                       Normal  Flying    251   40      45       40
# Pidgeotto                    Normal  Flying    349   63      60       55
# ...                             ...     ...    ...  ...     ...      ...
# Fletchinder                    Fire  Flying    382   62      73       55
# Talonflame                     Fire  Flying    499   78      81       71
# Vivillon                        Bug  Flying    411   80      52       50
# Hawlucha                   Fighting  Flying    500   78      92       75
# Yveltal                        Dark  Flying    680  126     131       95
#
#                            Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# Name
# ...

# %%
df[(df['Type 1']=="Psychic") & (df['Type 2']=="Flying")]
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary          Type-3
# Name
# Natu         70           2      False  Psychic+Flying
# Xatu         95           2      False  Psychic+Flying
# Lugia       110           2       True  Psychic+Flying
# Woobat       72           5      False  Psychic+Flying
# Swoobat     114           5      False  Psychic+Flying
# Sigilyph     97           5      False  Psychic+Flying

# %%
df[df['Type-3']=='Psychic+Flying']
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary          Type-3
# Name
# Natu         70           2      False  Psychic+Flying
# Xatu         95           2      False  Psychic+Flying
# Lugia       110           2       True  Psychic+Flying
# Woobat       72           5      False  Psychic+Flying
# Swoobat     114           5      False  Psychic+Flying
# Sigilyph     97           5      False  Psychic+Flying

# %% [markdown]
# ## Graded questions

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
df1=pd.read_csv('SA2021_W1_Pokemon.csv')
df1.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df1[df1.Name=="Mega"]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
df1[df1.Name.str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
df1.Name.str.contains('Mega').sum()
# Out:
# 49

# %%
#with df dataset
df.index.str.contains('Mega').sum()
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
df.head(2)
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  Grass  Poison    318  45      49       49       65       65     45
# Ivysaur    Grass  Poison    405  60      62       63       80       80     60
#
#            Generation  Legendary        Type-3
# Name
# Bulbasaur           1      False  Grass+Poison
# Ivysaur             1      False  Grass+Poison

# %%
df.columns
# Out:
# Index(['Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Type-3'],
#       dtype='object')

# %%
df['Sp. Def']
# Out:
# Name
# Bulbasaur                 65
# Ivysaur                   80
# Venusaur                 100
# VenusaurMega Venusaur    120
# Charmander                50
#                         ...
# Diancie                  150
# DiancieMega Diancie      110
# HoopaHoopa Confined      130
# HoopaHoopa Unbound       130
# Volcanion                 90
# Name: Sp. Def, Length: 800, dtype: int64

# %%
mean=df['Sp. Def'].mean()
mean
# Out:
# 71.9025

# %%
total=0
a=[]
for i in df['Sp. Def']:
    a.append((i-mean)**2)
a
# Out:
# [47.64450625000005,
#  65.56950624999995,
#  789.4695062499998,
#  2313.3695062499996,
#  479.71950625000017,
#  47.64450625000005,
#  171.5445062499999,
#  171.5445062499999,
#  1857.3945062499997,
#  62.449506250000056,
#  65.56950624999995,
#  1095.4445062499997,
#  1857.3945062499997,
#  2693.8695062500005,
#  2199.8445062500004,
#  65.56950624999995,
#  2693.8695062500005,
#  2199.8445062500004,
#  65.56950624999995,
#  65.56950624999995,
#  1361.7945062500003,
#  479.71950625000017,
#  3.619506250000013,
#  65.56950624999995,
#  1361.7945062500003,
#  3.619506250000013,
#  1673.0145062500003,
#  118.86450625000008,
#  320.49950625000014,
#  50.37450624999995,
#  479.71950625000017,
#  65.56950624999995,
#  1755.8195062500004,
#  285.69450625000013,
#  1017.7695062500002,
#  285.69450625000013,
#  171.5445062499999,
#  1017.7695062500002,
#  285.69450625000013,
#  9.594506249999979,
#  47.64450625000005,
#  327.5195062499999,
#  47.64450625000005,
#  789.4695062499998,
# ...

# %%
numerator=sum(a)
numerator
# Out:
# 618784.3949999994

# %%
sd=(numerator/(800-1))**0.5
sd
# Out:
# 27.82891579711745

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
df.head(2)
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  Grass  Poison    318  45      49       49       65       65     45
# Ivysaur    Grass  Poison    405  60      62       63       80       80     60
#
#            Generation  Legendary        Type-3
# Name
# Bulbasaur           1      False  Grass+Poison
# Ivysaur             1      False  Grass+Poison

# %%
df[df['Legendary']==True]
# Out:
#                        Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Articuno                  Ice    Flying    580   90      85      100       95
# Zapdos               Electric    Flying    580   90      90       85      125
# Moltres                  Fire    Flying    580   90     100       90      125
# Mewtwo                Psychic       NaN    680  106     110       90      154
# MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100      154
# ...                       ...       ...    ...  ...     ...      ...      ...
# Diancie                  Rock     Fairy    600   50     100      150      100
# DiancieMega Diancie      Rock     Fairy    700   50     160      110      160
# HoopaHoopa Confined   Psychic     Ghost    600   80     110       60      150
# HoopaHoopa Unbound    Psychic      Dark    680   80     160       60      170
# Volcanion                Fire     Water    600   80     110      120      130
#
# ...

# %%
df.Legendary.value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %%
df.Legendary.value_counts(normalize=True)
# Out:
# False    0.91875
# True     0.08125
# Name: Legendary, dtype: float64

# %%
#change bool to str
#df1['Legendary']=df1.Legendary.astype(str)

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
df.head(2)
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  Grass  Poison    318  45      49       49       65       65     45
# Ivysaur    Grass  Poison    405  60      62       63       80       80     60
#
#            Generation  Legendary        Type-3
# Name
# Bulbasaur           1      False  Grass+Poison
# Ivysaur             1      False  Grass+Poison

# %%
#method 1
df.Defense.sort_values(ascending=False)
# Out:
# Name
# SteelixMega Steelix    230
# Shuckle                230
# AggronMega Aggron      230
# Steelix                200
# Regirock               200
#                       ...
# Igglybuff               15
# Pichu                   15
# Blissey                 10
# Happiny                  5
# Chansey                  5
# Name: Defense, Length: 800, dtype: int64

# %%
df.Defense.sort_values(ascending=False).index[:3]
# Out:
# Index(['SteelixMega Steelix', 'Shuckle', 'AggronMega Aggron'], dtype='object', name='Name')

# %%
#method 2
df.Defense.max()
# Out:
# 230

# %%
df.Defense.value_counts()[230]
# Out:
# 3

# %%
df[df.Defense==230]
# Out:
#                     Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# Shuckle                Bug    Rock    505  20      10      230       10
# AggronMega Aggron    Steel     NaN    630  70     140      230       60
#
#                      Sp. Def  Speed  Generation  Legendary        Type-3
# Name
# SteelixMega Steelix       95     30           2      False  Steel+Ground
# Shuckle                  230      5           2      False      Bug+Rock
# AggronMega Aggron         80     50           3      False           NaN

# %%
df[df.Defense==230].index
# Out:
# Index(['SteelixMega Steelix', 'Shuckle', 'AggronMega Aggron'], dtype='object', name='Name')

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
df['Type-3'].str.contains('Poison').index
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X',
#        'CharizardMega Charizard Y', 'Squirtle',
#        ...
#        'Noibat', 'Noivern', 'Xerneas', 'Yveltal', 'Zygarde50% Forme',
#        'Diancie', 'DiancieMega Diancie', 'HoopaHoopa Confined',
#        'HoopaHoopa Unbound', 'Volcanion'],
#       dtype='object', name='Name', length=800)

# %%
#method 1
df[df['Type 1']=='Poison'].Attack.sort_values(ascending=False).head(1)
# Out:
# Name
# Toxicroak    106
# Name: Attack, dtype: int64

# %%
df[df['Type 2']=='Poison'].Attack.sort_values(ascending=False).head(1)
# Out:
# Name
# BeedrillMega Beedrill    150
# Name: Attack, dtype: int64

# %%
#method 2
df.head(2)
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  Grass  Poison    318  45      49       49       65       65     45
# Ivysaur    Grass  Poison    405  60      62       63       80       80     60
#
#            Generation  Legendary        Type-3
# Name
# Bulbasaur           1      False  Grass+Poison
# Ivysaur             1      False  Grass+Poison

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df[df['Type-3']=='Poison+Poison']
# Out:
# Empty DataFrame
# Columns: [Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, Type-3]
# Index: []

# %%
df[df['Type 1']=='Poison'].head(2)
# Out:
#        Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Ekans  Poison    NaN    288  35      60       44       40       54     55
# Arbok  Poison    NaN    438  60      85       69       65       79     80
#
#        Generation  Legendary Type-3
# Name
# Ekans           1      False    NaN
# Arbok           1      False    NaN

# %%
df[df['Type 1']=='Poison'].Attack.max()
# Out:
# 106

# %%
df[df['Type 2']=='Poison'].Attack.max()
# Out:
# 150

# %%
df[df['Type 2']=='Poison'].Attack
# Out:
# Name
# Bulbasaur                 49
# Ivysaur                   62
# Venusaur                  82
# VenusaurMega Venusaur    100
# Weedle                    35
# Kakuna                    25
# Beedrill                  90
# BeedrillMega Beedrill    150
# Oddish                    50
# Gloom                     65
# Vileplume                 80
# Venonat                   55
# Venomoth                  65
# Bellsprout                75
# Weepinbell                90
# Victreebel               105
# Tentacool                 40
# Tentacruel                70
# Gastly                    35
# Haunter                   50
# Gengar                    65
# GengarMega Gengar         65
# Spinarak                  60
# Ariados                   90
# Qwilfish                  95
# Dustox                    50
# Roselia                   60
# Budew                     30
# Roserade                  70
# Venipede                  45
# Whirlipede                55
# Scolipede                100
# ...

# %%
df[df['Type 2']=='Poison'].Attack.sort_values(ascending=False).head(1)
# Out:
# Name
# BeedrillMega Beedrill    150
# Name: Attack, dtype: int64

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
import seaborn as sns
sns.set()

# %%
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary        Type-3
# Name
# Bulbasaur                   65     45           1      False  Grass+Poison
# Ivysaur                     80     60           1      False  Grass+Poison
# Venusaur                   100     80           1      False  Grass+Poison
# VenusaurMega Venusaur      120     80           1      False  Grass+Poison
# Charmander                  50     65           1      False           NaN

# %%
df.Total.value_counts()
# Out:
# 600    37
# 405    26
# 500    23
# 580    23
# 300    19
#        ..
# 448     1
# 454     1
# 456     1
# 461     1
# 180     1
# Name: Total, Length: 200, dtype: int64

# %%
sns.distplot(df['Total'])

# %%
sns.distplot(df['HP'])

# %%
sns.boxplot(df['HP'])

# %% [markdown]
# We can see few outlier

# %%
sns.distplot(df['Attack'])

# %%
sns.distplot(df['Defense'])

# %%
sns.boxplot(df['Generation'])

# %%
#relation between 2 numerical columns
sns.scatterplot(x=df.HP,y=df.Attack)

# %% [markdown]
# AS HP increases, Attack also increases

# %%
#relation between 1 numerical and 1 categorical
sns.scatterplot(x=df['Generation'],y=df['Type 1'])

# %%
sns.boxplot(x=df.Legendary,y=df.Generation)

# %%
#few null values in column type 2
sns.heatmap(df1.isnull())

# %%
df.head(2)
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  Grass  Poison    318  45      49       49       65       65     45
# Ivysaur    Grass  Poison    405  60      62       63       80       80     60
#
#            Generation  Legendary        Type-3
# Name
# Bulbasaur           1      False  Grass+Poison
# Ivysaur             1      False  Grass+Poison

# %% [markdown]
# Generation 4 has more no. of Pokemons than generation 6 but less than that of generation 1
# True

# %%
df[df.Generation==4]['Generation'].count()
# Out:
# 121

# %%
df[df.Generation==6]['Generation'].count()
# Out:
# 82

# %%
df[df.Generation==1]['Generation'].count()
# Out:
# 166

# %% [markdown]
# Fairy' is less common Type-2 than 'Steele' and 'Psychic'
# False

# %%
df[df['Type 2']=='Steel']['Type 2'].count()
# Out:
# 22

# %%
df[df['Type 2']=='Psychic']['Type 2'].count()
# Out:
# 33

# %%
df[df['Type 2']=='Fairy']['Type 2'].count()
# Out:
# 23

# %% [markdown]
# Generation 3 has most no. of legendary pokemons.
# True

# %%
df.Generation.unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %%
df[(df.Generation==3) & (df.Legendary==True)].index.nunique()
# Out:
# 18

# %%
df[(df.Generation==1) & (df.Legendary==True)].index.nunique()
# Out:
# 6

# %%
df[(df.Generation==2) & (df.Legendary==True)].index.nunique()
# Out:
# 5

# %%
df[(df.Generation==4) & (df.Legendary==True)].index.nunique()
# Out:
# 13

# %%
df[(df.Generation==5) & (df.Legendary==True)].index.nunique()
# Out:
# 15

# %%
df[(df.Generation==6) & (df.Legendary==True)].index.nunique()
# Out:
# 8

# %% [markdown]
# There are total 6 pokemons with type-1 as 'Psychic' and type 2 as 'Flying'
# True

# %%
df[(df['Type 1']=='Psychic') & (df['Type 2']=='Flying')]
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary          Type-3
# Name
# Natu         70           2      False  Psychic+Flying
# Xatu         95           2      False  Psychic+Flying
# Lugia       110           2       True  Psychic+Flying
# Woobat       72           5      False  Psychic+Flying
# Swoobat     114           5      False  Psychic+Flying
# Sigilyph     97           5      False  Psychic+Flying

# %% [markdown]
# Flying is least common Type-1 followed by Ice
# False

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
df.head(2)
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  Grass  Poison    318  45      49       49       65       65     45
# Ivysaur    Grass  Poison    405  60      62       63       80       80     60
#
#            Generation  Legendary        Type-3
# Name
# Bulbasaur           1      False  Grass+Poison
# Ivysaur             1      False  Grass+Poison

# %%
#method 1
df[(df.Legendary==False) & (df['Type 1']=='Ghost') & (df.Generation==4)].Speed.sort_values(ascending=False)
# Out:
# Name
# Mismagius    105
# Drifblim      80
# Drifloon      70
# Dusknoir      45
# Spiritomb     35
# Name: Speed, dtype: int64

# %%
df[(df.Legendary==False) & (df['Type 1']=='Ghost') & (df.Generation==4)].Speed.sort_values(ascending=False).index[1]
# Out:
# 'Drifblim'

# %%
df[(df.Legendary==False) & (df['Type 2']=='Ghost') & (df.Generation==4)].Speed.sort_values(ascending=False)
# Out:
# Name
# Froslass    110
# Rotom        91
# Name: Speed, dtype: int64

# %%
df[(df.Legendary==False) & (df['Type 2']=='Ghost') & (df.Generation==4)].Speed.sort_values(ascending=False).index[1]
# Out:
# 'Rotom'

# %% [markdown]
# Roton is second fastest pokemon

# %%
#method 2 - longer way
df[df.Legendary==False]
# Out:
#                        Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur               Grass  Poison    318  45      49       49       65
# Ivysaur                 Grass  Poison    405  60      62       63       80
# Venusaur                Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur   Grass  Poison    625  80     100      123      122
# Charmander               Fire     NaN    309  39      52       43       60
# ...                       ...     ...    ...  ..     ...      ...      ...
# GourgeistSuper Size     Ghost   Grass    494  85     100      122       58
# Bergmite                  Ice     NaN    304  55      69       85       32
# Avalugg                   Ice     NaN    514  95     117      184       44
# Noibat                 Flying  Dragon    245  40      30       35       45
# Noivern                Flying  Dragon    535  85      70       80       97
#
# ...

# %%
df[df['Type 1']=='Ghost']
# Out:
#                       Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Gastly                 Ghost  Poison    310   30      35       30      100
# Haunter                Ghost  Poison    405   45      50       45      115
# Gengar                 Ghost  Poison    500   60      65       60      130
# GengarMega Gengar      Ghost  Poison    600   60      65       80      170
# Misdreavus             Ghost     NaN    435   60      60       60       85
# Shuppet                Ghost     NaN    295   44      75       35       63
# Banette                Ghost     NaN    455   64     115       65       83
# BanetteMega Banette    Ghost     NaN    555   64     165       75       93
# Duskull                Ghost     NaN    295   20      40       90       30
# Dusclops               Ghost     NaN    455   40      70      130       60
# Drifloon               Ghost  Flying    348   90      50       34       60
# ...

# %%
df[df.Generation==4]
# Out:
#                    Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Turtwig             Grass       NaN    318   55      68       64       45
# Grotle              Grass       NaN    405   75      89       85       55
# Torterra            Grass    Ground    525   95     109      105       75
# Chimchar             Fire       NaN    309   44      58       44       58
# Monferno             Fire  Fighting    405   64      78       52       78
# ...                   ...       ...    ...  ...     ...      ...      ...
# Manaphy             Water       NaN    600  100     100      100      100
# Darkrai              Dark       NaN    600   70      90       90      135
# ShayminLand Forme   Grass       NaN    600  100     100      100      100
# ShayminSky Forme    Grass    Flying    600  100     103       75      120
# Arceus             Normal       NaN    720  120     120      120      120
#
#                    Sp. Def  Speed  Generation  Legendary         Type-3
# ...

# %%
df.Speed.sort_values(ascending=False)
# Out:
# Name
# DeoxysSpeed Forme        180
# Ninjask                  160
# DeoxysNormal Forme       150
# AlakazamMega Alakazam    150
# DeoxysAttack Forme       150
#                         ...
# Trapinch                  10
# Bonsly                    10
# Ferroseed                 10
# Shuckle                    5
# Munchlax                   5
# Name: Speed, Length: 800, dtype: int64

# %%
a=df.Speed.sort_values(ascending=False)

# %%
b=df.Legendary==False

# %%
c=pd.concat([a,b],axis=1)
c
# Out:
#                        Speed  Legendary
# DeoxysSpeed Forme        180      False
# Ninjask                  160       True
# DeoxysNormal Forme       150      False
# AlakazamMega Alakazam    150       True
# DeoxysAttack Forme       150      False
# ...                      ...        ...
# Trapinch                  10       True
# Bonsly                    10       True
# Ferroseed                 10       True
# Shuckle                    5       True
# Munchlax                   5       True
#
# [800 rows x 2 columns]

# %%
d=df.Generation==4

# %%
e=df['Type 1']=='Ghost'

# %%
f=pd.concat([d,e],axis=1)
f
# Out:
#                        Generation  Type 1
# Name
# Bulbasaur                   False   False
# Ivysaur                     False   False
# Venusaur                    False   False
# VenusaurMega Venusaur       False   False
# Charmander                  False   False
# ...                           ...     ...
# Diancie                     False   False
# DiancieMega Diancie         False   False
# HoopaHoopa Confined         False   False
# HoopaHoopa Unbound          False   False
# Volcanion                   False   False
#
# [800 rows x 2 columns]

# %%
aa=pd.concat([c,f],axis=1)
aa
# Out:
#                        Speed  Legendary  Generation  Type 1
# DeoxysSpeed Forme        180      False       False   False
# Ninjask                  160       True       False   False
# DeoxysNormal Forme       150      False       False   False
# AlakazamMega Alakazam    150       True       False   False
# DeoxysAttack Forme       150      False       False   False
# ...                      ...        ...         ...     ...
# Trapinch                  10       True       False   False
# Bonsly                    10       True        True   False
# Ferroseed                 10       True       False   False
# Shuckle                    5       True       False   False
# Munchlax                   5       True        True   False
#
# [800 rows x 4 columns]

# %%
aa[(aa.Legendary==True) & (aa.Generation==True) & (aa['Type 1']==True)]
# Out:
#            Speed  Legendary  Generation  Type 1
# Mismagius    105       True        True    True
# Drifblim      80       True        True    True
# Drifloon      70       True        True    True
# Dusknoir      45       True        True    True
# Spiritomb     35       True        True    True

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary        Type-3
# Name
# Bulbasaur                   65     45           1      False  Grass+Poison
# Ivysaur                     80     60           1      False  Grass+Poison
# Venusaur                   100     80           1      False  Grass+Poison
# VenusaurMega Venusaur      120     80           1      False  Grass+Poison
# Charmander                  50     65           1      False           NaN

# %%
df.index.unique()
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard', 'CharizardMega Charizard X',
#        'CharizardMega Charizard Y', 'Squirtle',
#        ...
#        'Noibat', 'Noivern', 'Xerneas', 'Yveltal', 'Zygarde50% Forme',
#        'Diancie', 'DiancieMega Diancie', 'HoopaHoopa Confined',
#        'HoopaHoopa Unbound', 'Volcanion'],
#       dtype='object', name='Name', length=800)

# %%
df.loc[['Charizard',]]
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Charizard   Fire  Flying    534  78      84       78      109       85    100
#
#            Generation  Legendary       Type-3
# Name
# Charizard           1      False  Fire+Flying

# %%
df[(df.Legendary==False) & (df.Defense>78) & (df.Attack<84)]
# Out:
#                      Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Venusaur              Grass  Poison    525  80      82       83      100
# Wartortle             Water     NaN    405  59      63       80       65
# Blastoise             Water     NaN    530  79      83      100       85
# PidgeotMega Pidgeot  Normal  Flying    579  83      80       80      135
# Sandshrew            Ground     NaN    300  50      75       85       20
# ...                     ...     ...    ...  ..     ...      ...      ...
# Clawitzer             Water     NaN    500  71      73       88      120
# Carbink                Rock   Fairy    500  50      50      150       50
# Klefki                Steel   Fairy    470  57      80       91       80
# Bergmite                Ice     NaN    304  55      69       85       32
# Noivern              Flying  Dragon    535  85      70       80       97
#
#                      Sp. Def  Speed  Generation  Legendary         Type-3
# Name
# ...

# %%
df[(df.Legendary==False) & (df.Defense>78) & (df.Attack<84)].index
# Out:
# Index(['Venusaur', 'Wartortle', 'Blastoise', 'PidgeotMega Pidgeot',
#        'Sandshrew', 'Vileplume', 'Geodude', 'Slowbro', 'SlowbroMega Slowbro',
#        'Magneton',
#        ...
#        'Quilladin', 'Honedge', 'AegislashShield Forme', 'Slurpuff', 'Dragalge',
#        'Clawitzer', 'Carbink', 'Klefki', 'Bergmite', 'Noivern'],
#       dtype='object', name='Name', length=116)

# %%
df[(df.Legendary==False) & (df.Defense>78) & (df.Attack<84)].index.nunique()
# Out:
# 116

# %%
df1[(df1.Legendary==False) & (df1.Defense>78) & (df1.Attack<84)].Name.count()
# Out:
# 116

# %% [markdown]
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
df.head()
# Out:
#                       Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur              Grass  Poison    318  45      49       49       65
# Ivysaur                Grass  Poison    405  60      62       63       80
# Venusaur               Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# Charmander              Fire     NaN    309  39      52       43       60
#
#                        Sp. Def  Speed  Generation  Legendary        Type-3
# Name
# Bulbasaur                   65     45           1      False  Grass+Poison
# Ivysaur                     80     60           1      False  Grass+Poison
# Venusaur                   100     80           1      False  Grass+Poison
# VenusaurMega Venusaur      120     80           1      False  Grass+Poison
# Charmander                  50     65           1      False           NaN

# %%
df['Attack+Spl.Attack']=df['Attack']+df['Sp. Atk']
df['Attack+Spl.Attack']
# Out:
# Name
# Bulbasaur                114
# Ivysaur                  142
# Venusaur                 182
# VenusaurMega Venusaur    222
# Charmander               112
#                         ...
# Diancie                  200
# DiancieMega Diancie      320
# HoopaHoopa Confined      260
# HoopaHoopa Unbound       330
# Volcanion                240
# Name: Attack+Spl.Attack, Length: 800, dtype: int64

# %%
df['Attack+Spl.Attack'].sort_values(ascending=False).head(2)
# Out:
# Name
# RayquazaMega Rayquaza    360
# DeoxysAttack Forme       360
# Name: Attack+Spl.Attack, dtype: int64

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
df1[df1.Legendary==True]['Type 1'].value_counts().head(1)
# Out:
# Psychic    14
# Name: Type 1, dtype: int64

# %%
df1[df1.Legendary==True]['Type 2'].value_counts().head(1)
# Out:
# Flying    13
# Name: Type 2, dtype: int64

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
df.head(1)
# Out:
#           Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  Grass  Poison    318  45      49       49       65       65     45
#
#            Generation  Legendary        Type-3  Attack+Spl.Attack
# Name
# Bulbasaur           1      False  Grass+Poison                114

# %%
df[(df.Generation==3) & (df.Legendary==False)].HP.count()
# Out:
# 142

# %%
df[(df.Generation==6) & (df.Legendary==True)].HP.count()
# Out:
# 8

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
df['Speed'].max()
# Out:
# 180

# %%
df['Speed'].sort_values(ascending=False).head(10)
# Out:
# Name
# DeoxysSpeed Forme            180
# Ninjask                      160
# DeoxysNormal Forme           150
# AlakazamMega Alakazam        150
# DeoxysAttack Forme           150
# AerodactylMega Aerodactyl    150
# BeedrillMega Beedrill        145
# SceptileMega Sceptile        145
# Accelgor                     145
# Electrode                    140
# Name: Speed, dtype: int64

# %%
df['Speed'].sort_values(ascending=False).index[2:6]
# Out:
# Index(['DeoxysNormal Forme', 'AlakazamMega Alakazam', 'DeoxysAttack Forme',
#        'AerodactylMega Aerodactyl'],
#       dtype='object', name='Name')

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
df.columns
# Out:
# Index(['Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Type-3',
#        'Attack+Spl.Attack'],
#       dtype='object')

# %%
df['HP'].sort_values(ascending=False).head(1)
# Out:
# Name
# Blissey    255
# Name: HP, dtype: int64
